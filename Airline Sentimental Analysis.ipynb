# %%
# !pip install datasets
# !pip install scikit-learn
# !pip install ibm-cos-sdk
# !pip install ibm-watson-machine-learning==1.0.312

import os, getpass
from pandas import read_csv

credentials = {
    "url": "https://us-south.ml.cloud.ibm.com",
    "apikey": getpass.getpass("Please enter your WML api key (hit enter): ")
}
try:
    project_id = os.environ["PROJECT_ID"]
except KeyError:
    project_id = input("Please enter your project_id (hit enter): ")

project_id

import os, types
import pandas as pd
from ibm_boto3 import client
from botocore.client import Config
import ibm_boto3

def _iter_(self): return 0
cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='8u3B3f1qguU4sIG7hXaApPEDQtWa5bx3GxH4yoc1ewpU',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us-south.cloud-object-storage.appdomain.cloud'
)

bucket = 'bucket-iyfcx9vcyrd5l23'
object_key = 'airline_feedback_train.csv'

body = cos_client.get_object(Bucket=bucket, Key=object_key)['Body']
body = cos_client.get_object(Bucket=bucket, Key=object_key)['Body']

if not hasattr(body, "_iter"): body.iter_ = types.MethodType(_iter_, body)

train_data = pd.read_csv(body)
train_data.head(5)

import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def _iter_(self): return 0

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='8u3B3f1qguU4sIG7hXaApPEDQtWa5bx3GxH4yoc1ewpU',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us-south.cloud-object-storage.appdomain.cloud'
)
bucket = 'bucket-iyfcx9vcyrd5l23'
object_key = 'airline_feedback_test.csv'

body = cos_client.get_object(Bucket=bucket, Key=object_key)['Body']

# add missing _iter_ method, so pandas accepts body as file-like object
if not hasattr(body, "_iter"): body.iter_ = types.MethodType(_iter_, body)

test_data = pd.read_csv(body)
test_data.head(5)
train_data.shape
test_data.shape

from ibm_watson_machine_learning.foundation_models.utils.enums import ModelTypes

model_id = ModelTypes.FLAN_UL2

satisfaction_instruction = """
What is the sentiment of the customer? 
Classify it as negative, positive, or neutral.

review: The food was okay, nothing special.
sentiment: Neutral

review: The crew was very helpful and kind.
sentiment: Positive

review: I missed my flight due to poor communication.
sentiment: Negative

review:
"""


from ibm_watson_machine_learning.metanames import GenTextParamsMetaNames as GenParams

parameters = {
    GenParams.MAX_NEW_TOKENS: 20
}

from ibm_watson_machine_learning.foundation_models import Model

model = Model(
    model_id=model_id,
    params=parameters,
    credentials=credentials,
    project_id=project_id
)

import time

results = []
feedback = list(test_data.review_text)
sentiment = list(test_data.sentiment)

for input_text in feedback:
    prompt = " ".join([satisfaction_instruction, input_text])
    results.append(model.generate_text(prompt=prompt))
    time.sleep(0.6)  # Sleep to avoid hitting the rate limit
    feedback = list(test_data.review_text)
    sentiment = list(test_data.sentiment)

feedback
# Out:
# Please enter your WML api key (hit enter):  ········
# ['Seats provided standard comfort levels with no standout features.',
#  'Turbulence was intense, with no calming reassurances.',
#  'The service offered was aligned with the ticket price.',
#  'Meal trays were left uncleared for an extended period.',
#  'Legroom was severely limited, making the journey uncomfortable.',
#  'Missed connecting flight due to uncommunicated delays.',
#  'Children were not given water despite multiple requests.',
#  'Layovers were well-timed, ensuring smooth connections.',
#  'Nothing particularly remarkable; the journey was adequately comfortable.',
#  'Complimentary beverages were appreciated and served promptly.',
#  'Amenities such as clean blankets and pillows enhanced comfort.',
#  'Check-in and security procedures were swift and well-organized.',
#  'Luggage was slightly delayed but arrived intact.',
#  'The flight arrived ahead of schedule and was exceptionally smooth.',
#  'Temperature control could have been better regulated.',
#  'Delay announcements lacked transparency.',
#  'Window shade was damaged and unadjustable.',
#  'Professional commitments were missed due to long delays.',
#  'The captain communicated clearly and kept passengers well-informed.',
#  'Flight was overbooked, resulting in passenger removal.',
#  'Checked-in luggage was mishandled and not returned.',
#  'Boarding was structured but moved slowly.',
#  'Incorrect boarding passes caused unnecessary confusion.',
#  'Personal belongings such as a stroller were lost.',
#  'The captain provided timely updates on route and weather.',
#  'No power outlets were available for device charging.',
#  'Cabin crew were inattentive to passenger concerns and requests.',
#  'Crying child was not attended to by the crew.',
#  'Neighboring passenger’s constant coughing was disturbing.',
#  'Personal entertainment system failed to function.',
#  'Entertainment options appeared outdated.',
#  'A broad selection of in-flight entertainment was available.',
#  'Staff assistance for passengers with special needs was exemplary.',
#  'Overhead storage was adequate but required effort to manage.',
#  'Air conditioning was inconsistent, causing discomfort.',
#  'Window seat provided limited visibility due to fog.',
#  'Wi-Fi service failed after purchase with no refund option.',
#  'Onboard snacks were overpriced and of low quality.',
#  'Crew skipped basic safety checks during turbulence.',
#  'Flight attendants were polite, cheerful, and highly professional.',
#  'Disposable cutlery was used during meals.',
#  'Seat back was overly upright and slightly uncomfortable.',
#  'The airline accommodated dietary preferences thoughtfully.',
#  'Crew responded when approached for assistance.',
#  'Service met expectations but did not exceed them.',
#  'Announcements were made but lacked clarity in parts.',
#  'The overall flight experience was satisfactory and uneventful.',
#  'Limited product range in the onboard shopping catalog.',
#  'Meal service skipped our row without explanation.',
#  'Nothing significantly positive or negative occurred.',
#  'Cabin lighting created a calm and relaxing atmosphere.',
#  'Mobile check-in was convenient and expedited the process.',
#  'Gate change was last-minute and not announced clearly.',
#  'The airline mobile app malfunctioned during check-in.',
#  'Excessively long queues at check-in lacked ventilation.',
#  'Air circulation was passable but not ideal.',
#  'Safety instructions were delivered effectively and attentively.',
#  'The aircraft was modern, immaculate, and well-maintained.',
#  'No particular element stood out during the journey.',
#  'Cabin crew maintained attentive care throughout the flight.',
#  'Children were provided with engaging onboard activities.',
#  'Captain failed to address passengers during turbulence.',
#  'Announcements were overly loud at times.',
#  'Crew members were helpful in assisting with seating arrangements.',
#  'Baggage was delivered promptly and without damage.',
#  'Cabin temperature was slightly warmer than preferred.',
#  'The flight was delayed for several hours without clear communication.',
#  'Restrooms remained clean and hygienic during the entire flight.',
#  'Restroom facilities were unsanitary and unmaintained.',
#  'Delayed gate pushback was offset by fast taxiing.',
#  'Zone-wise boarding process ensured smooth transitions.',
#  'Vegetarian meal option was unavailable despite pre-request.',
#  'Customer support via phone was unhelpful and rude.',
#  'Snacks were limited in quantity but sufficient.',
#  'Tray tables and seating areas were spotless and ready for use.',
#  'The in-flight meal exceeded expectations in both taste and quality.',
#  'Cabin cleanliness was below acceptable standards.',
#  'Ground staff were efficient and welcoming.',
#  'A strong sense of safety was maintained throughout the trip.',
#  'Diversion of flight was poorly managed and unclear.',
#  'USB ports for charging were available at each seat.',
#  'The overall boarding and takeoff process was seamless.',
#  'Repeated call button alerts went unanswered.',
#  'Flight adhered closely to its scheduled timeline.',
#  'Meal service was basic, with no notable highlights.',
#  'Cabin crew seemed fatigued during the later part of flight.',
#  'Tray table had minor cleanliness issues.',
#  'Access to the airport lounge was a valuable perk.',
#  'Boarding announcements were professional and clearly articulated.',
#  'Disembarkation was smooth and efficiently managed.',
#  'Blankets were not provided despite cold night conditions.',
#  'Extra legroom seat turned out to be misleadingly marketed.',
#  'Seats were in poor condition and lacked basic cleanliness.',
#  'Departure lounge was crowded and noisy.',
#  'An unexpected upgrade at the gate added to a pleasant journey.',
#  'Flight attendants were consistently responsive and approachable.',
#  'Only paid meal options were available onboard.',
#  'Mild turbulence was encountered but well-handled.',
#  'Flight duration felt manageable and passed quickly.',
#  'Crew addressed passengers in an unprofessional tone.',
#  'Even economy class service was commendably high-quality.',
#  'Legroom in economy class was surprisingly generous.',
#  'Security protocols were routine and standard.',
#  'Landing was exceptionally smooth and expertly managed.',
#  'Ground staff displayed unprofessional and discourteous behavior.',
#  'An overhead compartment opened unexpectedly mid-flight.',
#  'Seats reclined comfortably without disturbing fellow passengers.',
#  'Flight crew acknowledged my birthday, which was a lovely gesture.',
#  'The fare aligned with the overall experience delivered.',
#  'The ambiance was peaceful, with minimal noise disturbances.',
#  'Flight reached the destination ahead of the scheduled time.',
#  'No entertainment was available, which was expected for a short flight.',
#  'Some delay was experienced in accessing the jet bridge.',
#  'Landing was abrupt, leading to discomfort.',
#  'Cabin baggage was denied entry despite visible space.',
#  'Cabin lighting was brighter than necessary at times.',
#  'Cabin crew spilled a drink without issuing an apology.',
#  'Seat recline function was broken and unusable.',
#  'Luggage was returned damaged and with missing parts.',
#  'The journey was turbulence-free and comfortable.',
#  'Boarding process was chaotic and poorly supervised.',
#  'Staff interactions were minimal and polite.',
#  'The crew performed their duties without significant engagement.',
#  'The airline app provided timely and helpful notifications.',
#  'Tray table functionality was impaired but usable.',
#  'A complimentary welcome drink enhanced the initial experience.',
#  'Passenger noise levels slightly affected the comfort.',
#  'Minor delay occurred but had limited impact.',
#  'Safety and hygiene measures such as masks were provided.',
#  'Meals served were cold, poorly presented, and lacked taste.',
#  'Check-in took longer than anticipated due to limited counters.',
#  'Requested a blanket twice before it was provided.',
#  'Water requests were repeatedly ignored during the flight.',
#  'Restroom queues were extended mid-flight.',
#  'Seats offered great comfort, and the cabin crew was highly courteous.',
#  'Business class amenities provided a serene and luxurious experience.',
#  'Hidden charges for baggage caused inconvenience.',
#  'Staff demonstrated sarcasm and unwillingness to assist.',
#  'The pilot personally greeted passengers upon arrival.',
#  'Unexpected seat selection fees were charged.',
#  'Persistent restroom odor made the journey unpleasant.',
#  'Flight departed and landed on time with no disruptions.',
#  'Baggage claim was efficient and hassle-free.',
#  'Boarding was efficient and executed in an orderly manner.',
#  'Multilingual staff ensured clarity for all passengers.',
#  'Seatbelt mechanism was faulty and posed a safety risk.',
#  'Middle seat offered just enough space to sit comfortably.',
#  'Stable and fast in-flight Wi-Fi enhanced the travel experience.',
#  'Family members were assigned non-adjacent seats.',
#  'Only one round of water service was conducted.']

# %%
sentiment
# Out:
# ['neutral',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral']

# %%
results
# Out:
# ['negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative']
